# %% [markdown]
# # Data Structures

# %% [markdown]
# Study about these
# - Primitive
# - Derived

# %% [markdown]
# ## Types
# - List
# - Tuple
# - dictionary
# - set

# %% [markdown]
# ## List

# %%
 lst = ["Dinesh", 20, '134224536', "College", 89.456475675] # this is how we create a list using square brackets

# %%
# Accessing

# %%
lst[0] # in python we have positive as well as negative indexing and negative starts from last
# Out:
# 'Dinesh'

# %%
lst[-5]
# Out:
# 'Dinesh'

# %%
# Indexing

# %%
lst[0:2] # indexing we do not include last index
# Out:
# ['Dinesh', 20]

# %%
lst[-1]
# Out:
# 89.456475675

# %%
lst[-3:]
# Out:
# ['134224536', 'College', 89.456475675]

# %%
# len

# %%
len(lst)
# Out:
# 5

# %%
# methods

# %%
# Method and attribute difference

# %%
lst
# Out:
# ['Dinesh', 20, '134224536', 'College', 89.456475675]

# %%
try:
    lst[5] = "ECE" 
except IndexError as e:
    print(e)
# we can't assign new values like this
# Out:
# list assignment index out of range

# %%
lst.append("ECE")

# %%
lst[5]
# Out:
# 'ECE'

# %%
lst.append(["ECE", "3rd year"]) # append adds the value as a single element in the list

# %%
lst
# Out:
# ['Dinesh',
#  20,
#  '134224536',
#  'College',
#  89.456475675,
#  'ECE',
#  ['ECE', '3rd year']]

# %%
try:
    lst[7]
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %%
len(lst)
# Out:
# 7

# %%
lst.extend([16, 12, 13]) # extend assigns different indices

# %%
lst
# Out:
# ['Dinesh',
#  20,
#  '134224536',
#  'College',
#  89.456475675,
#  'ECE',
#  ['ECE', '3rd year'],
#  16,
#  12,
#  13]

# %%
lst[0]
# Out:
# 'Dinesh'

# %%
lst[0]= "Dinesh Chowdary" # Updating elements

# %%
lst
# Out:
# ['Dinesh Chowdary',
#  20,
#  '134224536',
#  'College',
#  89.456475675,
#  'ECE',
#  ['ECE', '3rd year'],
#  16,
#  12,
#  13]

# %%
lst.insert(2, "FH3435352") # insert only inserts at a specific index without deleting the element present at that location

# %%
lst
# Out:
# ['Dinesh Chowdary',
#  20,
#  'FH3435352',
#  '134224536',
#  'College',
#  89.456475675,
#  'ECE',
#  ['ECE', '3rd year'],
#  16,
#  12,
#  13]

# %%
lst.remove("FH3435352") # remove directly removes the specified element without need of an index

# %%
lst
# Out:
# ['Dinesh Chowdary',
#  20,
#  '134224536',
#  'College',
#  89.456475675,
#  'ECE',
#  ['ECE', '3rd year'],
#  16,
#  12,
#  13]

# %%
lst.pop() # pops the last element of the list
# Out:
# 13

# %%
lst
# Out:
# ['Dinesh Chowdary',
#  20,
#  '134224536',
#  'College',
#  89.456475675,
#  'ECE',
#  ['ECE', '3rd year'],
#  16,
#  12]

# %%
save = lst.pop() # pop returns the popped element and also deletes it from the list

# %%
lst
# Out:
# ['Dinesh Chowdary',
#  20,
#  '134224536',
#  'College',
#  89.456475675,
#  'ECE',
#  ['ECE', '3rd year'],
#  16]

# %%
save
# Out:
# 12

# %%
lst.append(save)

# %%
lst
# Out:
# ['Dinesh Chowdary',
#  20,
#  '134224536',
#  'College',
#  89.456475675,
#  'ECE',
#  ['ECE', '3rd year'],
#  16,
#  12]

# %%
lst.pop()
# Out:
# 12

# %%
lst.pop()
# Out:
# 16

# %%
lst
# Out:
# ['Dinesh Chowdary',
#  20,
#  '134224536',
#  'College',
#  89.456475675,
#  'ECE',
#  ['ECE', '3rd year']]

# %%
lst.pop(3) # we can pop a specific element by it's position
# Out:
# 'College'

# %%
lst
# Out:
# ['Dinesh Chowdary', 20, '134224536', 89.456475675, 'ECE', ['ECE', '3rd year']]

# %%
del lst[0] # deletes the element

# %%
lst
# Out:
# [20, '134224536', 89.456475675, 'ECE', ['ECE', '3rd year']]

# %%
lst.insert(0, "Name")

# %%
lst
# Out:
# ['Name', 20, '134224536', 89.456475675, 'ECE', ['ECE', '3rd year']]

# %%
try:
    lst.sort()
except TypeError as e:
    print(e)
# Out:
# '<' not supported between instances of 'int' and 'str'

# %%
lst1 = [1,5,2,5,7,8]

# %%
lst1.sort()

# %%
lst1
# Out:
# [1, 2, 5, 5, 7, 8]

# %%
lst1.reverse()

# %%
lst1
# Out:
# [8, 7, 5, 5, 2, 1]

# %%
lst1.clear()

# %%
lst1
# Out:
# []

# %%
del lst1 # deletes the list

# %%
# Indexing and Slicing
lst1 = [[1,3,5,[3,6, 8]]]

# %%
len(lst1)
# Out:
# 1

# %%
details = lst.copy() # copy the list useful for storing as backup

# %%
details
# Out:
# ['Name', 20, '134224536', 89.456475675, 'ECE', ['ECE', '3rd year']]
