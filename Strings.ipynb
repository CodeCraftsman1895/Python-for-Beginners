# %%
Name = "Dinesh"
peru = 'Dinesh' # we can write strings in either single quote or double quote
naam = """This is a multiline string
we can write in as many lines as we want without the escape character"""
# string is immutable

# %%
# difference between compiler and interpretor

# %%
Name[0:3] # slicing the first three values of a string
# Out:
# 'Din'

# %%
len(Name)
# Out:
# 6

# %%
Name[-1] # python also contains negative indexing we can access from the end starting from -1
# Out:
# 'h'

# %%
Name[0]
# Out:
# 'D'

# %%
Name[:] # full slice from start to end
# Out:
# 'Dinesh'

# %%
# Doc strings
def func():
    """Sum of two numbers
    """
help(func)  # Docstrings are used to explain about a function and can be accessed using help function 
# Docstring contains the description of function and ways to debug if there is some issue # study about the rules to write docstrings
# Out:
# Help on function func in module __main__:
#
# func()
#     Sum of two numbers

# %%
Name.lower() # converts the string to lower case
# Out:
# 'dinesh'

# %%
Name.upper() # converts the string to upper case
# Out:
# 'DINESH'

# %%
hel = "     my name is so and so       "

# %%
hel.strip() # removes the extra spaces from both left and right
# Out:
# 'my name is so and so'

# %%
hel.lstrip() # removes extra spaces on left side
# Out:
# 'my name is so and so       '

# %%
hel.rstrip() # removes extra spaces on right side
# Out:
# '     my name is so and so'

# %%
hel.title() # converts the first letter of every word in string to capital
# Out:
# '     My Name Is So And So       '

# %%
hel.capitalize() # converts the first character of string to capital 
# here the first character is space so there is no change
# Out:
# '     my name is so and so       '

# %%
hel.split(sep = "so") # split the string whenever you see "so" in the string
# Out:
# ['     my name is ', ' and ', '       ']

# %%
Name.count('Jah') # counts the occurence of the character or substring in a string
# Out:
# 0

# %%
hel.isalpha() # checks if the string contains alphabets only
# Out:
# False

# %%
sgf = "235345"
sgf.isdigit() # checks if the string contains numbers(not float values -- only numbers) only
# Out:
# True

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print('Dinesh\'s world') # escape character is used to print the required output without messing the syntax of print
# Out:
# Dinesh's world

# %%
print("Hello\b World!") # backspace - removes one letter before it
# Out:
# Hell World!

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ![image.png](attachment:d83beade-63e9-4835-81ab-85c2f5f27b48.png)

# %%
print('Dinesh\'s \nworld')
# Out:
# Dinesh's
# world

# %%
print("Welcome to 'Hyderabad'")
# Out:
# Welcome to 'Hyderabad'

# %%
print("Welcome to \"Hyderabad\"")
# Out:
# Welcome to "Hyderabad"

# %%
str1 = "I have a Good Day packet in which I have 30 biscuits"
print(str1)
# Out:
# I have a Good Day packet in which I have 30 biscuits

# %%
biscuit = input("Enter a biscuit brand name: ")
Quantity = input("Enter number of biscuits in the packet: ")
# Out:
# Enter a biscuit brand name:  Oreo
# Enter number of biscuits in the packet:  5

# %%
type(Quantity)
# Out:
# str

# %%
quan = 5

# %%
print(f"I have a {biscuit} packet in which I have {quan} biscuits") #f string - we can place any valid python expression in {}
# Out:
# I have a Oreo packet in which I have 5 biscuits

# %%
print("I have a {} packet in which I have {} biscuits".format(biscuit, Quantity)) # format method - embedding variables or values into place holders {}
# Out:
# I have a Oreo packet in which I have 5 biscuits

# %%
print("I have a {1} packet in which I have {0} biscuits".format(biscuit, Quantity)) # we can alter the order
# Out:
# I have a 5 packet in which I have Oreo biscuits

# %%
" ".join("Hello")
# Out:
# 'H e l l o'

# %%
lst = ["I have", "30", "Biscuits"]
" ".join(lst) # joins every element of the string using space
# Out:
# 'I have 30 Biscuits'

# %%
" ".join(Name) # joins every character of the string with a space
# Out:
# 'D i n e s h'

# %%
print(r'hi my name is \nDinesh') # raw string - print it as it is
# Out:
# hi my name is \nDinesh

# %%
print("I have","a","biscuit packet", sep = " ")
# Out:
# I have a biscuit packet

# %%
print(R'hi my name is \nDinesh') # raw string can be used with a capital R too
# Out:
# hi my name is \nDinesh

# %%
print("C:\\Users\\Dines\\OneDrive\\Documents") # it is difficult to print the path without the raw string
# Out:
# C:\Users\Dines\OneDrive\Documents

# %%
print("I have a biscuit packet", end= "\n") # end in a new line
# Out:
# I have a biscuit packet

# %%
str1
# Out:
# 'I have a Oreo packet in which I have 5 biscuits'

# %%
str1 = str1.replace("Good Day", "Oreo")
str1 = str1.replace("30", "5")

# %%
str1
# Out:
# 'I have a Oreo packet in which I have 5 biscuits'

# %%
nam = "Dinesh"
nem = "dinesh"
print (nam  < nem)
# Out:
# True

# %%
chr(65) # returns the character corresponding ascii value
# Out:
# 'A'

# %%
chr(90)
# Out:
# 'Z'

# %%
chr(97)
# Out:
# 'a'

# %%
chr(122)
# Out:
# 'z'

# %%
ord("A") # returns the ascii value of the respective character
# Out:
# 65

# %%
sum1 = 0
for letter in Name.lower():
    sum1 += ord(letter)

# %%
sum1
# Out:
# 635
